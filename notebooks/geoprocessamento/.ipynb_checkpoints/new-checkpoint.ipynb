# %%
import geopandas as gpd
import matplotlib

# %%
path_list = ['municipios.shp','rodovias2024.shp'] 
dados = [gpd.read_file(i) for i in path_list]

# %%
municipios_filter = dados[0][dados[0]['SIGLA_UF'] == 'PR']
rodovias = gpd.overlay(dados[1],municipios_filter, how='intersection')

# %%
municipios_filter
# Out:
#        CD_MUN               NM_MUN SIGLA_UF  AREA_KM2  \
# 3912  4100103               Abatiá       PR   228.717
# 3913  4100202         Adrianópolis       PR  1349.311
# 3914  4100301        Agudos do Sul       PR   192.261
# 3915  4100400  Almirante Tamandaré       PR   194.228
# 3916  4100459   Altamira do Paraná       PR   386.945
# ...       ...                  ...      ...       ...
# 4306  4128625         Alto Paraíso       PR   967.772
# 4307  4128633       Doutor Ulysses       PR   777.482
# 4308  4128658              Virmond       PR   249.094
# 4309  4128708             Vitorino       PR   308.218
# 4310  4128807               Xambrê       PR   359.712
#
#                                                geometry
# 3912  POLYGON ((-50.31709 -23.35594, -50.3201 -23.35...
# 3913  POLYGON ((-48.74044 -24.86835, -48.83801 -24.8...
# 3914  POLYGON ((-49.29618 -26.08673, -49.2962 -26.08...
# 3915  POLYGON ((-49.25401 -25.31913, -49.25402 -25.3...
# 3916  POLYGON ((-52.71774 -24.85776, -52.7184 -24.85...
# ...                                                 ...
# 4306  POLYGON ((-53.94556 -23.64963, -53.95576 -23.6...
# 4307  POLYGON ((-49.34065 -24.75685, -49.34082 -24.7...
# 4308  POLYGON ((-52.16911 -25.38702, -52.16953 -25.3...
# 4309  POLYGON ((-52.77092 -26.24167, -52.77001 -26.2...
# 4310  POLYGON ((-53.46995 -23.75652, -53.47002 -23.7...
#
# [399 rows x 5 columns]

# %%
municipios_filter.plot()
# Out:
# <Axes: >

# %%
rodovias.plot()
# Out:
# <Axes: >
